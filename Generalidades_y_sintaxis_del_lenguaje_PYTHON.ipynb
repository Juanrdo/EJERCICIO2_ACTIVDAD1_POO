# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanrdo/EJERCICIO2_ACTIVDAD1_POO/blob/main/Generalidades_y_sintaxis_del_lenguaje_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🐍Generalidades y sintaxis del lenguaje Python 🐍**

# %% [markdown]
# <center>
#
#
# ## **👨‍💻🧑‍💻👩‍💻👨‍💻🧑‍💻👩‍💻👩‍💻👨‍💻👨‍💻👨‍💻🧑‍💻👩‍💻👨‍💻👩‍💻🧑‍💻👨‍💻👩‍💻🧑‍💻👩‍💻👨‍💻🧑‍💻👩‍💻👨‍💻🧑‍💻👩‍💻👩‍💻👨‍💻👨‍💻👨‍💻🧑‍💻👩‍💻👨‍💻👩‍💻**
#
# ## **Generalidades y sintaxis del lenguaje Python**
#
# <center>
#
# ![200.gif](data:image/gif;base64,...)
#
#
# </center>
#
# ## **Asignatura**
#
#   Programación Orientada a Objetos
#
# ## **Profesor**
#   Jaime Alberto Guzmán Luna
#
#
#
# ## **Universidad Nacional de Colombia**
# ## **Sede Medellín**
# ## **2024 - 2**
#
# ## **👨‍💻🧑‍💻👩‍💻👨‍💻🧑‍💻👩‍💻👩‍💻👨‍💻👨‍💻👨‍💻🧑‍💻👩‍💻👨‍💻👩‍💻🧑‍💻👨‍💻👩‍💻🧑‍💻👩‍💻👨‍💻🧑‍💻👩‍💻👨‍💻🧑‍💻👩‍💻👩‍💻👨‍💻👨‍💻👨‍💻🧑‍💻👩‍💻👨‍💻👩‍💻**
#
#
# </center>

# %% [markdown]
# <center>

# %% [markdown]
# ## **Generalidades de Python**

# %% [markdown]
# <div align="justify">
#
# Python es un lenguaje interpretado y multiparadigma que admite diversos enfoques de programación, como la orientación a objetos (OOP), la programación imperativa y la programación funcional. Es un lenguaje de tipado dinámico, multiplataforma y multipropósito, utilizado principalmente para el desarrollo web y la creación de aplicaciones informáticas.
#
# <center>
#
# ![220167426-0c5f630e-6d56-4617-9775-71c2bd025b4f.gif](data:image/gif;base64,...)
#
#
# </center>
#
# </div>

# %% [markdown]
# <center>

# %% [markdown]
# **Interpretado**

# %% [markdown]
# <div align="justify">
#
# Los lenguajes interpretados son aquellos en los que el código se traduce y ejecuta mediante un intérprete a medida que se necesita, en lugar de ser compilado previamente. Algunos ejemplos comunes de lenguajes interpretados son Python, Ruby y JavaScript.
#
# **Ventajas de los lenguajes interpretados:**
#
# - No es necesario compilar, lo que ahorra tiempo en el desarrollo y la prueba de aplicaciones, ya que el código se ejecuta directamente.
#
# - Portabilidad: El código fuente puede ejecutarse en cualquier sistema que tenga el intérprete adecuado, ya sea Windows, Linux, Mac, Android, o incluso aplicaciones web.
#
# **¿Por qué Python es fácil de aprender?**
#
# - Simplicidad: Python tiene una sintaxis clara y sencilla que se enfoca en la legibilidad del código, lo que facilita su aprendizaje y uso en comparación con otros lenguajes.
#
# - Facilita la colaboración: La simplicidad y legibilidad de Python permiten que varios desarrolladores trabajen en el mismo proyecto sin grandes barreras de comprensión, lo que reduce los costos de mantenimiento y mejora la eficiencia del equipo.
#
#
#
#
# </div>

# %% [markdown]
# <center>

# %% [markdown]
# **Tipado dinámico**

# %% [markdown]
# <div align="justify">
#
# El tipado dinámico significa que en un lenguaje de programación como Python, las variables pueden cambiar su tipo de datos durante la ejecución del programa. No es necesario definir de antemano el tipo de dato que va a contener la variable, ya que Python determina automáticamente el tipo según el valor que se le asigne.
#
#
# </div>

# %% [markdown]
# **🧑‍💻Ejemplo 1👩‍💻**

# %%
x = 10        # x es un entero (int)
x = "Hola"    # Ahora x es una cadena de texto (str)
x = 3.14      # Ahora x es un número decimal (float)

# %% [markdown]
# <center>

# %% [markdown]
# **🧑‍💻Ejemplo 2👩‍💻**

# %%
a = 1
print(type(a))
# En este punto, 'a' tiene el valor 1, que es un número entero (int).
# Por lo tanto, type(a) devolverá <class 'int'>.

a = "b"
print(type(a))
# Ahora 'a' se ha reasignado a la cadena de texto "b".
# Python cambia automáticamente el tipo de 'a' a 'str' (cadena de texto).
# type(a) devolverá <class 'str'>.

a = []
print(type(a))
# Finalmente, 'a' se reasigna a una lista vacía ([]).
# Una vez más, Python ajusta automáticamente el tipo de 'a', que ahora es 'list'.
# type(a) devolverá <class 'list'>.
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %% [markdown]
# <div align="justify">
# Básicamente vamos a guardar en ella lo que queremos y python automáticamente detectara su tipo, no hace falta que se lo indiquemos.
#
# </div>

# %% [markdown]
# <center>

# %% [markdown]
# **Tipos de datos**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# </center>

# %% [markdown]
# **Simples**

# %% [markdown]
# - **Números Enteros (int)**
#
#     - Descripción: Representan números enteros sin parte decimal.

# %% [markdown]
# **🧑‍💻Ejemplo 3👩‍💻**

# %%
numero_entero = 10
print(type(numero_entero))  # Resultado: <class 'int'>
print(numero_entero)  # Imprime: 10
# Out:
# <class 'int'>
# 10

# %% [markdown]
# - **Números Decimales (float)**
#
#     - Descripción: Representan números reales con parte decimal.

# %% [markdown]
# **🧑‍💻Ejemplo 4👩‍💻**

# %%
numero_decimal = 3.1416
print(type(numero_decimal))  # Resultado: <class 'float'>
print(numero_decimal)  # Imprime: 3.1416
# Out:
# <class 'float'>
# 3.1416

# %% [markdown]
# - **Booleano (bool)**
#
#      - Descripción: Representa valores lógicos, que solo pueden ser Verdadero (True) o Falso (False).

# %% [markdown]
# **🧑‍💻Ejemplo 5👩‍💻**

# %%
es_verdadero = True
es_falso = False
print(type(es_verdadero))  # Resultado: <class 'bool'>
print(es_verdadero)  # Imprime: True
print(es_falso)  # Imprime: False
# Out:
# <class 'bool'>
# True
# False

# %% [markdown]
# - **Carácter (char)**
#
#     - **Nota:** En Python no existe un tipo específico para caracteres (como en C o Java), pero se pueden representar como una cadena de texto de longitud 1.

# %% [markdown]
# **🧑‍💻Ejemplo 6👩‍💻**

# %%
caracter = 'a'
print(type(caracter))  # Resultado: <class 'str'>
print(caracter)  # Imprime: a
# Out:
# <class 'str'>
# a

# %% [markdown]
# **Compuestos**

# %% [markdown]
# - **Cadenas de Texto (str)**
#
#      - Descripción: Representan secuencias de caracteres (como palabras o frases).

# %% [markdown]
# **🧑‍💻Ejemplo 7👩‍💻**

# %%
cadena_texto = "Hola, mundo"
print(type(cadena_texto))  # Resultado: <class 'str'>
print(cadena_texto)  # Imprime: Hola, mundo
# Out:
# <class 'str'>
# Hola, mundo

# %% [markdown]
# - **Listas (list)**
#
#      - Descripción: Colecciones de elementos ordenados y modificables.

# %% [markdown]
# **🧑‍💻Ejemplo 8👩‍💻**

# %%
lista = [1, 2, 3, 4]
print(type(lista))  # Resultado: <class 'list'>
print(lista)  # Imprime: [1, 2, 3, 4]
# Out:
# <class 'list'>
# [1, 2, 3, 4]

# %% [markdown]
# - **Tuplas (tuple)**
#
#     - Descripción: Colecciones de elementos ordenados pero inmutables (no se pueden modificar después de su creación).

# %% [markdown]
# **🧑‍💻Ejemplo 9👩‍💻**

# %%
tupla = (1, 2, 3)
print(type(tupla))  # Resultado: <class 'tuple'>
print(tupla)  # Imprime: (1, 2, 3)
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %% [markdown]
# **🧑‍💻Ejemplo 10👩‍💻**

# %%
tupla = 1, 2, 3
print(type(tupla))  # Resultado: <class 'tuple'>
print(tupla)  # Imprime: (1, 2, 3)
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %% [markdown]
# - **Diccionarios (dict)**
#
#     - Descripción: Estructuras de datos que almacenan pares clave-valor.

# %% [markdown]
# **🧑‍💻Ejemplo 11👩‍💻**

# %%
diccionario = {"nombre": "Ana", "edad": 25}
print(type(diccionario))  # Resultado: <class 'dict'>
print(diccionario)  # Imprime: {'nombre': 'Ana', 'edad': 25}
# Out:
# <class 'dict'>
# {'nombre': 'Ana', 'edad': 25}

# %% [markdown]
# - **Conjuntos (set)**
#
#      - Descripción: Colecciones no ordenadas de elementos únicos.

# %% [markdown]
# **🧑‍💻Ejemplo 12👩‍💻**

# %%
conjunto = {1, 2, 3, 4, 5}
print(type(conjunto))  # Resultado: <class 'set'>
print(conjunto)  # Imprime: {1, 2, 3, 4, 5}
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5}

# %% [markdown]
# <center>

# %% [markdown]
# **Conversión de tipos**

# %% [markdown]
# <div align="justify">
#
# La conversión de datos o cast se refiere al proceso de cambiar un valor de un tipo de dato a otro. Existen dos tipos principales de conversión de datos: conversión implícita y conversión explícita, cada una utilizada en diferentes situaciones dependiendo de si el lenguaje permite la conversión automática o requiere intervención manual.
#
# </div>

# %% [markdown]
# - **Conversión implícita**
#
# <div align="justify">
#
# La conversión implícita de tipos en Python ocurre de manera automática, sin que el programador tenga que intervenir. Python realiza esta conversión cuando se llevan a cabo operaciones entre dos tipos de datos diferentes. Aunque suele ser útil, es importante entender cómo funciona para evitar errores o resultados inesperados en el programa.
#
#
# </div>

# %% [markdown]
# **🧑‍💻Ejemplo 13👩‍💻**

# %%
a = 1  # Variable 'a' es un entero (int)
b = 2.3  # Variable 'b' es un decimal (float)

a = a + b  # Python convierte automáticamente 'a' de int a float
print(type(a))  # Resultado: <class 'float'>
# La conversión implícita ocurre aquí porque al sumar un entero y un decimal, Python automáticamente convierte el resultado a float.

# Sin embargo, hay casos en los que no se puede realizar la conversión automáticamente
a = 1  # Variable 'a' es un entero (int)
b = "2.3"  # Variable 'b' es una cadena de texto (string)

c = a + b  # Este código genera un error de tipo (TypeError)
# Python no puede sumar un entero con una cadena directamente, por lo que se debe hacer una conversión explícita.

# %% [markdown]
# - **Conversión explicita**

# %% [markdown]
# <div align="justify">
#
# En Python, también podemos realizar conversiones explícitas entre tipos de datos utilizando funciones específicas que proporciona el lenguaje. Estas conversiones, también conocidas como castings, nos permiten cambiar manualmente el tipo de un valor a otro. A continuación se presentan las funciones de conversión más utilizadas:
#
#
# </div>

# %% [markdown]
# - **int() – Convierte a entero:**
#
#      - Convierte un valor numérico o una cadena que representa un número a tipo entero (int).

# %% [markdown]
# **🧑‍💻Ejemplo 14👩‍💻**

# %%
a = int(3.5)  # Convierte el número decimal 3.5 a 3 (entero)
b = int("10")  # Convierte la cadena "10" en el entero 10
print(a, b)  # Imprime: 3 10

# %% [markdown]
# - **float() – Convierte a decimal:**
#
#      - Convierte un valor numérico o una cadena que representa un número a tipo decimal (float).

# %% [markdown]
# **🧑‍💻Ejemplo 15👩‍💻**

# %%
a = float(5)  # Convierte el entero 5 a 5.0 (decimal)
b = float("2.3")  # Convierte la cadena "2.3" a 2.3 (decimal)
print(a, b)  # Imprime: 5.0 2.3

# %% [markdown]
# - **str() – Convierte a cadena de texto:**
#
#      - Convierte un valor numérico o cualquier otro tipo de dato a tipo cadena (str).

# %% [markdown]
# **🧑‍💻Ejemplo 16👩‍💻**

# %%
a = str(10)  # Convierte el entero 10 a la cadena "10"
b = str(3.14)  # Convierte el decimal 3.14 a la cadena "3.14"
print(a, b)  # Imprime: 10 3.14

# %% [markdown]
# - **bool() – Convierte a booleano:**
#
#      - Convierte un valor a tipo booleano (bool), donde 0, None, y cadenas vacías son consideradas False, mientras que otros valores son considerados True

# %% [markdown]
# **🧑‍💻Ejemplo 17👩‍💻**

# %%
a = bool(1)  # Convierte el valor 1 a True
b = bool(0)  # Convierte el valor 0 a False
c = bool("")  # Cadena vacía se convierte a False
print(a, b, c)  # Imprime: True False False

# %% [markdown]
# <center>

# %% [markdown]
# **Imprimir por consola**

# %% [markdown]
# <div align="justify">
#
# En Python, para imprimir algo en la consola, utilizamos la función print(). Esta función se encarga de mostrar cualquier tipo de dato en la salida estándar (normalmente la consola).
#
# </div>

# %% [markdown]
# **🧑‍💻Ejemplo 18👩‍💻**

# %%
print("Hola, mundo")  # Imprime una cadena de texto

# %% [markdown]
# **🧑‍💻Ejemplo 19👩‍💻**

# %%
nombre = "Ana"
edad = 25
print("Mi nombre es", nombre, "y tengo", edad, "años.")

# %% [markdown]
# <center>

# %% [markdown]
# **Funciones**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
#
# </center>

# %% [markdown]
# <div align="justify">
#
# En Python, una función es un bloque de código reutilizable que realiza una tarea específica. Las funciones permiten organizar el código en partes más pequeñas y manejables, mejorando la legibilidad y facilitando su mantenimiento. Además, evitan la duplicación de código, ya que podemos llamar a una función tantas veces como sea necesario en diferentes partes de un programa.
#
# </div>

# %% [markdown]
# **🧑‍💻Ejemplo 20👩‍💻**

# %%
def nombre_funcion(parametros):
    # Cuerpo de la función
    return resultado

# %% [markdown]
# **🧑‍💻Ejemplo 21👩‍💻**

# %%
def saludar(nombre):
    return f"Hola, {nombre}!"

mensaje = saludar("Ana")
print(mensaje)  # Imprime: Hola, Ana!

# %% [markdown]
# <center>

# %% [markdown]
# **Estructuras condicionales y bucles en Python**

# %% [markdown]
# - **if (condicional)**
#
#     - La estructura if permite ejecutar un bloque de código solo si una condición es verdadera.

# %% [markdown]
# **🧑‍💻Ejemplo 22👩‍💻**

# %%
edad = 18

if edad >= 18:
    print("Eres mayor de edad.")

# %% [markdown]
# - **if - else (condicional con alternativa)**
#     - Si la condición del if es falsa, puedes usar el bloque else para ejecutar un bloque de código alternativo.

# %% [markdown]
# **🧑‍💻Ejemplo 23👩‍💻**

# %%
edad = 16

if edad >= 18:
    print("Eres mayor de edad.")
else:
    print("Eres menor de edad.")

# %% [markdown]
# - **if - elif - else (múltiples condiciones)**
#
#     - Cuando tienes varias condiciones, puedes usar elif para agregar más comprobaciones.

# %% [markdown]
# **🧑‍💻Ejemplo 24👩‍💻**

# %%
nota = 85

if nota >= 90:
    print("Excelente")
elif nota >= 70:
    print("Aprobado")
else:
    print("Reprobado")

# %% [markdown]
# - **for (bucle iterativo)**
#
#    - El bucle for en Python se utiliza para iterar sobre una secuencia (como una lista, tupla, diccionario, cadena o rango).

# %% [markdown]
# **🧑‍💻Ejemplo 25👩‍💻**

# %%
frutas = ["manzana", "banana", "naranja"]

for fruta in frutas:
    print(fruta)

# %% [markdown]
# - **for-else (bucle con clausula else)**
#
#     - El bucle for-else es una característica única de Python. El bloque else se ejecuta cuando el bucle termina normalmente, es decir, si no se interrumpe con un break.

# %% [markdown]
# **🧑‍💻Ejemplo 26👩‍💻**

# %%
numeros = [1, 2, 3, 4]

for num in numeros:
    if num == 5:
        print("Encontrado 5")
        break
else:
    print("No se encontró el número 5")
# Out:
# No se encontró el número 5

# %% [markdown]
# - **while (bucle condicional)**
#
#     - El bucle while repite el bloque de código mientras una condición sea verdadera.

# %% [markdown]
# **🧑‍💻Ejemplo 27👩‍💻**

# %%
contador = 0

while contador < 5:
    print(contador)
    contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# - **while-else (bucle con clausula else)**
#
#     - Al igual que con for-else, puedes usar else con un bucle while. El bloque else se ejecuta si el bucle no es interrumpido por un break.

# %% [markdown]
# **🧑‍💻Ejemplo 28👩‍💻**

# %%
contador = 0

while contador < 5:
    print(contador)
    contador += 1
else:
    print("El contador ha alcanzado 5.")
# Out:
# 0
# 1
# 2
# 3
# 4
# El contador ha alcanzado 5.

# %% [markdown]
# # <center>
#
# ![image.png](data:image/png;base64,...)
#
#
#
# </center>

# %% [markdown]
# - https://drive.google.com/file/d/1zP2YDSyd8EL7l-KlZNAPGTM3jqQa-XDq/view?usp=sharing
